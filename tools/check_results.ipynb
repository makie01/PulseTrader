# %%
import pandas as pd

df = pd.read_csv("../data/cross_platform_event_prompts.csv")
print(len(df))
# Out:
# 50

# %%
df = pd.read_csv("../data/cross_platform_event_results.csv")
arbitrage_possible = df[df["could_have_arbitrage"] == True]
print(len(arbitrage_possible))
arbitrage_possible
# Out:
# 16
#                kalshi_ticker  polymarket_id  similarity  \
# 1        KXGRETAGAZA-26JAN01          40869    0.953031
# 2               KXBTCMAXY-25          36173    0.948797
# 5       KXBTC2026250-27JAN01          36173    0.937557
# 18             KXLARGECUT-25          16085    0.929691
# 24            KXBOASTABLE-25          19687    0.926975
# 27          KXNFLNFCSOUTH-25          23667    0.926505
# 32           KXNFLNFCEAST-25          23664    0.924526
# 35          KXNFLNFCNORTH-25          23666    0.923633
# 36  KXFIFAUSPULLGAME-26JUN11          38368    0.923597
# 38          KXNFLAFCNORTH-25          23659    0.922965
# 39           KXLCPIMAXYOY-25          17880    0.922561
# 40          KXNFLNFCCHAMP-25          23657    0.922268
# 44           KXNFLNFCWEST-25          23665    0.921357
# 47          KXNFLAFCSOUTH-25          23660    0.920951
# 48          KXPRESPARTY-2028          33228    0.920862
# 49           KXNFLAFCEAST-25          23663    0.920660
#
#                                          kalshi_title  \
# 1           Will Greta Thunberg enter Gaza this year?
# 2                  How high will Bitcoin get in 2025?
# 5                Will Bitcoin be above $250k by 2027?
# 18  Will the Fed do a rate cut of more than 25bps ...
# 24  Will Bank of America launch a stablecoin in 2025?
# 27                         NFC South Division Winner?
# 32                          NFC East Division Winner?
# 35                         NFC North Division Winner?
# 36  Will any 2026 FIFA World Cup game scheduled in...
# 38                         AFC North Division Winner?
# 39     How high will the inflation level get in 2025?
# 40                           NFC Championship Winner?
# 44                          NFC West Division Winner?
# 47                         AFC South Division Winner?
# 48  Which party will win the 2028 Presidential Ele...
# 49                          AFC East Division Winner?
#
#                                      polymarket_title  kalshi_markets_count  \
# 1               Will Greta Thunberg enter Gaza by...?                     1
# 2                        When will Bitcoin hit $150k?                    12
# 5                        When will Bitcoin hit $150k?                     1
# 18                    How many Fed rate cuts in 2025?                     1
# 24             BOA launches a USD stablecoin in 2025?                     1
# 27                                   NFC South Winner                     2
# 32                                    NFC East Winner                     2
# 35                                  NFC North Winner                      3
# 36  Will any 2026 FIFA World Cup game scheduled in...                     1
# 38                                  AFC North Winner                      3
# 39               How high will inflation get in 2025?                     3
# 40                                      NFC Champion                     11
# 44                                   NFC West Winner                      3
# 47                                  AFC South Winner                      3
# 48    Which party wins 2028 US Presidential Election?                     2
# 49                                   AFC East Winner                      2
#
#     polymarket_markets_count  \
# 1                          1
# 2                          4
# 5                          4
# 18                         7
# 24                         1
# 27                         2
# 32                         2
# 35                         3
# 36                         1
# 38                         3
# 39                         6
# 40                        11
# 44                         3
# 47                         3
# 48                         2
# 49                         2
#
#                                                prompt  \
# 1   You are an expert in prediction markets and ev...
# 2   You are an expert in prediction markets and ev...
# 5   You are an expert in prediction markets and ev...
# 18  You are an expert in prediction markets and ev...
# 24  You are an expert in prediction markets and ev...
# 27  You are an expert in prediction markets and ev...
# 32  You are an expert in prediction markets and ev...
# 35  You are an expert in prediction markets and ev...
# 36  You are an expert in prediction markets and ev...
# 38  You are an expert in prediction markets and ev...
# 39  You are an expert in prediction markets and ev...
# 40  You are an expert in prediction markets and ev...
# 44  You are an expert in prediction markets and ev...
# 47  You are an expert in prediction markets and ev...
# 48  You are an expert in prediction markets and ev...
# 49  You are an expert in prediction markets and ev...
#
#                                      llm_raw_response  could_have_arbitrage  \
# 1   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 2   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 5   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 18  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 24  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 27  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 32  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 35  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 36  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 38  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 39  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 40  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 44  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 47  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 48  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 49  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
#
#                                               reasons  \
# 1   An arbitrage opportunity could exist because t...
# 2   Both platforms have markets asking if the pric...
# 5   A structural arbitrage opportunity could exist...
# 18  An arbitrage opportunity could exist because t...
# 24  Yes, an arbitrage opportunity could exist. The...
# 27  Both events cover the winner of the NFC South ...
# 32  The events on both platforms cover the winner ...
# 35  Both events cover the identical outcome: the w...
# 36  The markets cover the same fundamental questio...
# 38  Both platforms offer distinct Yes/No markets f...
# 39  Yes, an arbitrage opportunity exists due to a ...
# 40  Both platforms offer markets on the winner of ...
# 44  Both events cover the winner of the NFC West f...
# 47  Both events cover the winner of the AFC South ...
# 48  A structural arbitrage opportunity exists beca...
# 49  Both events offer markets on the exact same ou...
#
#                             matched_market_pairs_json  parse_error
# 1   [{"kalshi_market_ticker": "KXGRETAGAZA-26JAN01...          NaN
# 2   [{"kalshi_market_ticker": "KXBTCMAXY-25-DEC31-...          NaN
# 5   [{"kalshi_market_ticker": "KXBTC2026250-27JAN0...          NaN
# 18  [{"kalshi_market_ticker": "KXLARGECUT-25", "po...          NaN
# 24  [{"kalshi_market_ticker": "KXBOASTABLE-25", "p...          NaN
# 27  [{"kalshi_market_ticker": "KXNFLNFCSOUTH-25-TB...          NaN
# 32  [{"kalshi_market_ticker": "KXNFLNFCEAST-25-PHI...          NaN
# 35  [{"kalshi_market_ticker": "KXNFLNFCNORTH-25-DE...          NaN
# 36  [{"kalshi_market_ticker": "KXFIFAUSPULLGAME-26...          NaN
# 38  [{"kalshi_market_ticker": "KXNFLAFCNORTH-25-PI...          NaN
# 39  [{"kalshi_market_ticker": "KXLCPIMAXYOY-25-P3....          NaN
# 40  [{"kalshi_market_ticker": "KXNFLNFCCHAMP-25-CA...          NaN
# 44  [{"kalshi_market_ticker": "KXNFLNFCWEST-25-SF"...          NaN
# 47  [{"kalshi_market_ticker": "KXNFLAFCSOUTH-25-HO...          NaN
# 48  [{"kalshi_market_ticker": "KXPRESPARTY-2028-R"...          NaN
# 49  [{"kalshi_market_ticker": "KXNFLAFCEAST-25-BUF...          NaN
