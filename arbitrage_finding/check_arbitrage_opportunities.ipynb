# %%
import pandas as pd
import sys
import math
import json
from pathlib import Path
from typing import List, Dict, Any, Optional

# Add parent directory to path for imports
sys.path.insert(0, str(Path().resolve().parent))

from tools.markets import get_markets_for_event as get_kalshi_markets
from tools.polymarket import get_markets_for_event as get_polymarket_markets

# Trading fee rate for Kalshi (7% = 0.07)
# Note: Polymarket has NO trading fees
KALSHI_FEE_RATE = 0.07

def calculate_kalshi_trading_fee(price, contracts=1):
    """
    Calculate trading fee for Kalshi trades only.
    
    Formula: fees = round_up(0.07 x C x P x (1-P))
    - P = price of contract in dollars (0.5 for 50 cents)
    - C = number of contracts
    - 0.07 = 7% fee rate
    
    Note: Polymarket has NO trading fees, so this function is only for Kalshi.
    
    Args:
        price: Price of contract in dollars (0.0 to 1.0)
        contracts: Number of contracts (default 1 for per-$1 calculation)
    
    Returns:
        Fee in dollars
    """
    if price <= 0 or price >= 1:
        return 0.0
    
    fee = KALSHI_FEE_RATE * contracts * price * (1 - price)
    # Round up to next cent
    return math.ceil(fee * 100) / 100.0

# %%
# Load the results CSV to get pairs that have arbitrage potential
df = pd.read_csv("../data/cross_platform_event_results.csv")
arbitrage_possible = df[df["could_have_arbitrage"] == True]
print(f"Found {len(arbitrage_possible)} event pairs with potential arbitrage")
print(f"\nColumns: {arbitrage_possible.columns.tolist()}")
arbitrage_possible.head()
# Out:
# Found 16 event pairs with potential arbitrage
#
# Columns: ['kalshi_ticker', 'polymarket_id', 'similarity', 'kalshi_title', 'polymarket_title', 'kalshi_markets_count', 'polymarket_markets_count', 'prompt', 'llm_raw_response', 'could_have_arbitrage', 'reasons', 'matched_market_pairs_json', 'parse_error']
#            kalshi_ticker  polymarket_id  similarity  \
# 1    KXGRETAGAZA-26JAN01          40869    0.953031
# 2           KXBTCMAXY-25          36173    0.948797
# 5   KXBTC2026250-27JAN01          36173    0.937557
# 18         KXLARGECUT-25          16085    0.929691
# 24        KXBOASTABLE-25          19687    0.926975
#
#                                          kalshi_title  \
# 1           Will Greta Thunberg enter Gaza this year?
# 2                  How high will Bitcoin get in 2025?
# 5                Will Bitcoin be above $250k by 2027?
# 18  Will the Fed do a rate cut of more than 25bps ...
# 24  Will Bank of America launch a stablecoin in 2025?
#
#                           polymarket_title  kalshi_markets_count  \
# 1    Will Greta Thunberg enter Gaza by...?                     1
# 2             When will Bitcoin hit $150k?                    12
# 5             When will Bitcoin hit $150k?                     1
# 18         How many Fed rate cuts in 2025?                     1
# 24  BOA launches a USD stablecoin in 2025?                     1
#
#     polymarket_markets_count  \
# 1                          1
# 2                          4
# 5                          4
# 18                         7
# 24                         1
#
#                                                prompt  \
# 1   You are an expert in prediction markets and ev...
# 2   You are an expert in prediction markets and ev...
# 5   You are an expert in prediction markets and ev...
# 18  You are an expert in prediction markets and ev...
# 24  You are an expert in prediction markets and ev...
#
#                                      llm_raw_response  could_have_arbitrage  \
# 1   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 2   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 5   ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 18  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
# 24  ```json\n{\n  "could_have_arbitrage": true,\n ...                  True
#
#                                               reasons  \
# 1   An arbitrage opportunity could exist because t...
# 2   Both platforms have markets asking if the pric...
# 5   A structural arbitrage opportunity could exist...
# 18  An arbitrage opportunity could exist because t...
# 24  Yes, an arbitrage opportunity could exist. The...
#
#                             matched_market_pairs_json  parse_error
# 1   [{"kalshi_market_ticker": "KXGRETAGAZA-26JAN01...          NaN
# 2   [{"kalshi_market_ticker": "KXBTCMAXY-25-DEC31-...          NaN
# 5   [{"kalshi_market_ticker": "KXBTC2026250-27JAN0...          NaN
# 18  [{"kalshi_market_ticker": "KXLARGECUT-25", "po...          NaN
# 24  [{"kalshi_market_ticker": "KXBOASTABLE-25", "p...          NaN

# %%
# Price extraction functions
def get_polymarket_prices(market):
    """
    Extract YES and NO prices from a Polymarket market.
    
    Polymarket pricing:
    - YES price = bestAsk (what you pay to buy Yes)
    - NO price = 1 - bestBid (what you pay to buy No)
    """
    try:
        best_bid = market.get('bestBid')
        best_ask = market.get('bestAsk')
        
        yes_price = None
        no_price = None
        
        if best_ask is not None:
            yes_price = float(best_ask)
            # Validate price is in valid range
            if yes_price < 0 or yes_price > 1:
                yes_price = None
        
        if best_bid is not None:
            bid_val = float(best_bid)
            # Validate bid is in valid range
            if 0 <= bid_val <= 1:
                no_price = 1.0 - bid_val
                # Validate no_price is in valid range
                if no_price < 0 or no_price > 1:
                    no_price = None
        
        return yes_price, no_price
    except (ValueError, TypeError) as e:
        return None, None

def get_kalshi_prices(market):
    """
    Extract YES and NO prices from a Kalshi market.
    
    Kalshi pricing:
    - YES price = yes_ask (in cents, convert to decimal)
    - NO price = no_ask (in cents, convert to decimal)
    """
    try:
        yes_ask = market.get('yes_ask')
        no_ask = market.get('no_ask')
        
        yes_price = None
        no_price = None
        
        if yes_ask is not None:
            yes_price = float(yes_ask) / 100.0
            # Validate price is in valid range
            if yes_price < 0 or yes_price > 1:
                yes_price = None
        
        if no_ask is not None:
            no_price = float(no_ask) / 100.0
            # Validate price is in valid range
            if no_price < 0 or no_price > 1:
                no_price = None
        
        return yes_price, no_price
    except (ValueError, TypeError) as e:
        return None, None

# %%
def parse_matched_market_pairs(matched_pairs_json: str) -> List[Dict[str, Any]]:
    """
    Parse the matched_market_pairs_json string into a list of matched pairs.
    
    Format example:
    [
        {
            "kalshi_market_ticker": "KXNFLNFCEAST-25-PHI",
            "polymarket_market_id": "540286",
            "relationship": "same_outcome",
            "notes": "..."
        },
        ...
    ]
    
    IMPORTANT: An event may have many markets (e.g., 11 Kalshi markets, 4 Polymarket markets),
    but only SOME of those markets are matched (e.g., only 3 matched pairs in the JSON).
    We only check arbitrage for the matched pairs, not all combinations.
    
    Args:
        matched_pairs_json: JSON string containing matched market pairs
        
    Returns:
        List of dicts with 'kalshi_market_ticker' and 'polymarket_market_id' (or similar)
    """
    if not matched_pairs_json or pd.isna(matched_pairs_json) or matched_pairs_json.strip() == "":
        return []
    
    try:
        pairs = json.loads(matched_pairs_json)
        if isinstance(pairs, list):
            return pairs
        return []
    except (json.JSONDecodeError, TypeError) as e:
        print(f"Error parsing matched_market_pairs_json: {e}")
        return []


def find_market_by_ticker(markets: List[Dict[str, Any]], ticker: str) -> Optional[Dict[str, Any]]:
    """Find a Kalshi market by its ticker."""
    for market in markets:
        if market.get('ticker') == ticker:
            return market
    return None


def find_market_by_id(markets: List[Dict[str, Any]], market_id: Any) -> Optional[Dict[str, Any]]:
    """Find a Polymarket market by its ID."""
    # Try different possible ID fields
    market_id_str = str(market_id)
    for market in markets:
        # Check various ID fields
        if (str(market.get('id', '')) == market_id_str or
            str(market.get('market_id', '')) == market_id_str or
            str(market.get('slug', '')) == market_id_str):
            return market
    return None


def check_arbitrage_opportunity(
    kalshi_markets: List[Dict[str, Any]],
    polymarket_markets: List[Dict[str, Any]],
    matched_pairs: List[Dict[str, Any]]
) -> List[Dict[str, Any]]:
    """
    Check for arbitrage opportunities between matched Kalshi and Polymarket markets.
    
    Only checks markets that are in the matched_pairs list (markets that represent
    the same underlying question/outcome).
    
    Fee structure:
    - Polymarket: NO trading fees (fee = $0.00)
    - Kalshi: Fee = round_up(0.07 x C x P x (1-P))
      (Only charged on immediately matched orders - market orders)
    
    Arbitrage exists if: (poly_price + poly_fee) + (kalshi_price + kalshi_fee) < 1.0
    Since poly_fee = 0, this simplifies to: poly_price + (kalshi_price + kalshi_fee) < 1.0
    
    Args:
        kalshi_markets: List of all Kalshi markets for the event
        polymarket_markets: List of all Polymarket markets for the event
        matched_pairs: List of matched market pairs from JSON (each with kalshi_market_ticker and polymarket_market_id)
    
    Returns:
        List of arbitrage opportunities with details.
    """
    opportunities = []
    
    # Only check matched pairs, not all combinations
    # Note: An event may have many markets (e.g., 11 Kalshi markets, 4 Polymarket markets)
    # But we only check the markets that are in matched_pairs (e.g., 3 matched pairs)
    print(f"  Checking {len(matched_pairs)} matched market pair(s) for arbitrage...")
    print(f"  (Event has {len(kalshi_markets)} total Kalshi markets, {len(polymarket_markets)} total Polymarket markets)")
    
    for pair_idx, pair in enumerate(matched_pairs, 1):
        # Parse the matched pair - JSON format: {"kalshi_market_ticker": "...", "polymarket_market_id": "..."}
        kalshi_ticker = pair.get('kalshi_market_ticker')
        # Try different possible field names for Polymarket market ID
        polymarket_id = pair.get('polymarket_market_id') or pair.get('polymarket_id') or pair.get('poly_market_id')
        
        print(f"  Matched pair #{pair_idx}: Kalshi ticker={kalshi_ticker}, Polymarket ID={polymarket_id}")
        
        if not kalshi_ticker or not polymarket_id:
            print(f"    ⚠️  Missing ticker or ID, skipping")
            continue
        
        # Find the specific markets from the full event markets list
        kalshi_market = find_market_by_ticker(kalshi_markets, kalshi_ticker)
        poly_market = find_market_by_id(polymarket_markets, polymarket_id)

        if not kalshi_market:
            print(f"    ⚠️  Kalshi market {kalshi_ticker} not found in event markets")
            print(f"       Available Kalshi market tickers: {[m.get('ticker') for m in kalshi_markets[:5]]}")
            continue
        
        if not poly_market:
            print(f"    ⚠️  Polymarket market {polymarket_id} not found in event markets")
            print(f"       Available Polymarket market IDs: {[m.get('id') for m in polymarket_markets[:5]]}")
            continue
        
        # Confirm we found the correct markets
        print(f"    ✓ Found Kalshi market: {kalshi_market.get('ticker')} - {kalshi_market.get('title', 'N/A')[:50]}")
        print(f"    ✓ Found Polymarket market: {poly_market.get('id')} - {poly_market.get('question', 'N/A')[:50]}")
        
        # Extract prices
        poly_yes, poly_no = get_polymarket_prices(poly_market)
        kalshi_yes, kalshi_no = get_kalshi_prices(kalshi_market)
        
        if poly_yes is None or poly_no is None:
            print(f"    ⚠️  Missing prices for Polymarket market {polymarket_id}")
            continue
        
        if kalshi_yes is None or kalshi_no is None:
            print(f"    ⚠️  Missing prices for Kalshi market {kalshi_ticker}")
            continue
        
        # Strategy 1: Buy YES on Polymarket, Buy NO on Kalshi
        poly_yes_fee = 0.0  # Polymarket has no fees
        kalshi_no_fee = calculate_kalshi_trading_fee(kalshi_no, contracts=1)
        
        combo1_total_cost = poly_yes + poly_yes_fee + kalshi_no + kalshi_no_fee
        combo1_profit = 1.0 - combo1_total_cost
        
        # Strategy 2: Buy NO on Polymarket, Buy YES on Kalshi
        poly_no_fee = 0.0  # Polymarket has no fees
        kalshi_yes_fee = calculate_kalshi_trading_fee(kalshi_yes, contracts=1)
        
        combo2_total_cost = poly_no + poly_no_fee + kalshi_yes + kalshi_yes_fee
        combo2_profit = 1.0 - combo2_total_cost
        
        # Check if either combination is profitable
        pair_has_opportunity = False
        
        if combo1_profit > 0:
            print(f"    ✅ Found arbitrage opportunity: Strategy 1 (Buy YES Poly + Buy NO Kalshi), Profit: {combo1_profit*100:.2f}%")
            pair_has_opportunity = True
            opportunities.append({
                'strategy': 'Buy YES on Polymarket, Buy NO on Kalshi',
                'poly_market_id': poly_market.get('id'),
                'poly_market_title': poly_market.get('question'),
                'kalshi_market_ticker': kalshi_market.get('ticker'),
                'kalshi_market_title': kalshi_market.get('title'),
                'poly_yes_price': poly_yes,
                'poly_yes_fee': poly_yes_fee,  # Always 0.0
                'kalshi_no_price': kalshi_no,
                'kalshi_no_fee': kalshi_no_fee,
                'total_cost': combo1_total_cost,
                'total_fees': poly_yes_fee + kalshi_no_fee,  # Only Kalshi fees
                'profit': combo1_profit,
                'profit_pct': combo1_profit * 100
            })
        
        if combo2_profit > 0:
            print(f"    ✅ Found arbitrage opportunity: Strategy 2 (Buy NO Poly + Buy YES Kalshi), Profit: {combo2_profit*100:.2f}%")
            pair_has_opportunity = True
            opportunities.append({
                'strategy': 'Buy NO on Polymarket, Buy YES on Kalshi',
                'poly_market_id': poly_market.get('id'),
                'poly_market_title': poly_market.get('question'),
                'kalshi_market_ticker': kalshi_market.get('ticker'),
                'kalshi_market_title': kalshi_market.get('title'),
                'poly_no_price': poly_no,
                'poly_no_fee': poly_no_fee,  # Always 0.0
                'kalshi_yes_price': kalshi_yes,
                'kalshi_yes_fee': kalshi_yes_fee,
                'total_cost': combo2_total_cost,
                'total_fees': poly_no_fee + kalshi_yes_fee,  # Only Kalshi fees
                'profit': combo2_profit,
                'profit_pct': combo2_profit * 100
            })
        
        if not pair_has_opportunity:
            print(f"    ❌ No arbitrage opportunity for this matched pair")
            print(f"      Strategy 1 (Buy YES Poly + Buy NO Kalshi):")
            print(f"        Poly YES price: ${poly_yes:.4f} (fee: $0.00)")
            print(f"        Kalshi NO price: ${kalshi_no:.4f} (fee: ${kalshi_no_fee:.4f})")
            print(f"        Total cost: ${combo1_total_cost:.4f}, Profit: ${combo1_profit:.4f} ({combo1_profit*100:.2f}%)")
            print(f"      Strategy 2 (Buy NO Poly + Buy YES Kalshi):")
            print(f"        Poly NO price: ${poly_no:.4f} (fee: $0.00)")
            print(f"        Kalshi YES price: ${kalshi_yes:.4f} (fee: ${kalshi_yes_fee:.4f})")
            print(f"        Total cost: ${combo2_total_cost:.4f}, Profit: ${combo2_profit:.4f} ({combo2_profit*100:.2f}%)")
            print(f"      Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists")
    
    return opportunities

# %%
# Process each event pair and check for arbitrage
all_opportunities = []

for idx, row in arbitrage_possible.iterrows():
    kalshi_ticker = row.get('kalshi_ticker')
    polymarket_id = row.get('polymarket_id')
    matched_pairs_json = row.get('matched_market_pairs_json', '')
    
    print(f"\n{'='*80}")
    print(f"Processing pair {idx + 1}/{len(arbitrage_possible)}")
    print(f"Kalshi Event: {kalshi_ticker}")
    print(f"Polymarket Event ID: {polymarket_id}")
    print(f"Similarity: {row.get('similarity', 'N/A')}")
    
    # Parse matched market pairs
    matched_pairs = parse_matched_market_pairs(matched_pairs_json)
    print(f"Found {len(matched_pairs)} matched market pair(s) in JSON")
    
    if not matched_pairs:
        print("⚠️  No matched market pairs found, skipping this event pair")
        continue
    
    # Get all Kalshi markets for the event (needed to find specific matched markets)
    try:
        kalshi_markets = get_kalshi_markets(kalshi_ticker)
    except Exception as e:
        print(f"Error fetching Kalshi markets: {e}")
        kalshi_markets = []
    
    # Get all Polymarket markets for the event (needed to find specific matched markets)
    try:
        polymarket_markets = get_polymarket_markets(event_id=str(polymarket_id))
    except Exception as e:
        print(f"Error fetching Polymarket markets: {e}")
        polymarket_markets = []
    
    # Check for arbitrage opportunities only for matched pairs
    if kalshi_markets and polymarket_markets:
        opportunities = check_arbitrage_opportunity(kalshi_markets, polymarket_markets, matched_pairs)
    
        if opportunities:
            print(f"✅ Found {len(opportunities)} arbitrage opportunity(ies) across {len(matched_pairs)} matched pair(s)!")
            for opp in opportunities:
                opp['kalshi_event_ticker'] = kalshi_ticker
                opp['polymarket_event_id'] = polymarket_id
                all_opportunities.append(opp)
        else:
            print(f"❌ No arbitrage opportunities found for {len(matched_pairs)} matched pair(s)")
    else:
        print("⚠️  Missing market data, skipping")
# Out:
# ================================================================================
# Processing pair 2/16
# Kalshi Event: KXGRETAGAZA-26JAN01
# Polymarket Event ID: 40869
# Similarity: 0.9530305862426758
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  40869
#   Checking 1 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXGRETAGAZA-26JAN01, Polymarket ID=591900
#     ✅ Found arbitrage opportunity: Strategy 1 (Buy YES Poly + Buy NO Kalshi), Profit: 0.40%
# ✅ Found 1 arbitrage opportunity(ies) across 1 matched pair(s)!
#
# ================================================================================
# Processing pair 3/16
# Kalshi Event: KXBTCMAXY-25
# Polymarket Event ID: 36173
# Similarity: 0.948796570301056
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  36173
#   Checking 1 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXBTCMAXY-25-DEC31-149999.99, Polymarket ID=573653
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0150 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0150, Profit: $-0.0150 (-1.50%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9930 (fee: $0.00)
#         Kalshi YES price: $0.0200 (fee: $0.0100)
#         Total cost: $1.0230, Profit: $-0.0230 (-2.30%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 1 matched pair(s)
#
# ================================================================================
# Processing pair 6/16
# Kalshi Event: KXBTC2026250-27JAN01
# Polymarket Event ID: 36173
# Similarity: 0.937557339668274
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  36173
#   Checking 1 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXBTC2026250-27JAN01-250000, Polymarket ID=573656
#     ✅ Found arbitrage opportunity: Strategy 2 (Buy NO Poly + Buy YES Kalshi), Profit: 22.00%
# ✅ Found 1 arbitrage opportunity(ies) across 1 matched pair(s)!
#
# ================================================================================
# Processing pair 19/16
# Kalshi Event: KXLARGECUT-25
# Polymarket Event ID: 16085
# Similarity: 0.929691195487976
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  16085
# ⚠️  Missing market data, skipping
#
# ================================================================================
# Processing pair 25/16
# Kalshi Event: KXBOASTABLE-25
# Polymarket Event ID: 19687
# Similarity: 0.9269751310348512
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  19687
#   Checking 1 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXBOASTABLE-25, Polymarket ID=525283
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0300 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9890 (fee: $0.00)
#         Kalshi YES price: $0.0500 (fee: $0.0100)
#         Total cost: $1.0490, Profit: $-0.0490 (-4.90%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 1 matched pair(s)
#
# ================================================================================
# Processing pair 28/16
# Kalshi Event: KXNFLNFCSOUTH-25
# Polymarket Event ID: 23667
# Similarity: 0.926505446434021
# Found 2 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23667
#   Checking 2 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLNFCSOUTH-25-TB, Polymarket ID=540298
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.7300 (fee: $0.00)
#         Kalshi NO price: $0.2900 (fee: $0.0200)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.3100 (fee: $0.00)
#         Kalshi YES price: $0.7200 (fee: $0.0200)
#         Total cost: $1.0500, Profit: $-0.0500 (-5.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLNFCSOUTH-25-CAR, Polymarket ID=540301
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.2790 (fee: $0.00)
#         Kalshi NO price: $0.7100 (fee: $0.0200)
#         Total cost: $1.0090, Profit: $-0.0090 (-0.90%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.7230 (fee: $0.00)
#         Kalshi YES price: $0.3000 (fee: $0.0200)
#         Total cost: $1.0430, Profit: $-0.0430 (-4.30%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 2 matched pair(s)
#
# ================================================================================
# Processing pair 33/16
# Kalshi Event: KXNFLNFCEAST-25
# Polymarket Event ID: 23664
# Similarity: 0.9245256185531616
# Found 2 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23664
#   Checking 2 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLNFCEAST-25-PHI, Polymarket ID=540286
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.8970 (fee: $0.00)
#         Kalshi NO price: $0.1200 (fee: $0.0100)
#         Total cost: $1.0270, Profit: $-0.0270 (-2.70%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.1610 (fee: $0.00)
#         Kalshi YES price: $0.8900 (fee: $0.0100)
#         Total cost: $1.0610, Profit: $-0.0610 (-6.10%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLNFCEAST-25-DAL, Polymarket ID=540287
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.1620 (fee: $0.00)
#         Kalshi NO price: $0.9000 (fee: $0.0100)
#         Total cost: $1.0720, Profit: $-0.0720 (-7.20%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.8890 (fee: $0.00)
#         Kalshi YES price: $0.1100 (fee: $0.0100)
#         Total cost: $1.0090, Profit: $-0.0090 (-0.90%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 2 matched pair(s)
#
# ================================================================================
# Processing pair 36/16
# Kalshi Event: KXNFLNFCNORTH-25
# Polymarket Event ID: 23666
# Similarity: 0.9236333966255188
# Found 3 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23666
#   Checking 3 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLNFCNORTH-25-DET, Polymarket ID=540294
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0930 (fee: $0.00)
#         Kalshi NO price: $0.9100 (fee: $0.0100)
#         Total cost: $1.0130, Profit: $-0.0130 (-1.30%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9390 (fee: $0.00)
#         Kalshi YES price: $0.1000 (fee: $0.0100)
#         Total cost: $1.0490, Profit: $-0.0490 (-4.90%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLNFCNORTH-25-GB, Polymarket ID=540295
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.6900 (fee: $0.00)
#         Kalshi NO price: $0.3200 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.3500 (fee: $0.00)
#         Kalshi YES price: $0.6900 (fee: $0.0200)
#         Total cost: $1.0600, Profit: $-0.0600 (-6.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXNFLNFCNORTH-25-CHI, Polymarket ID=540297
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.2540 (fee: $0.00)
#         Kalshi NO price: $0.7600 (fee: $0.0200)
#         Total cost: $1.0340, Profit: $-0.0340 (-3.40%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.7650 (fee: $0.00)
#         Kalshi YES price: $0.2500 (fee: $0.0200)
#         Total cost: $1.0350, Profit: $-0.0350 (-3.50%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 3 matched pair(s)
#
# ================================================================================
# Processing pair 37/16
# Kalshi Event: KXFIFAUSPULLGAME-26JUN11
# Polymarket Event ID: 38368
# Similarity: 0.9235973954200744
# Found 1 matched market pair(s) in JSON
# fetching polymarket event using event_id:  38368
#   Checking 1 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXFIFAUSPULLGAME-26JUN11, Polymarket ID=578157
#     ✅ Found arbitrage opportunity: Strategy 2 (Buy NO Poly + Buy YES Kalshi), Profit: 3.00%
# ✅ Found 1 arbitrage opportunity(ies) across 1 matched pair(s)!
#
# ================================================================================
# Processing pair 39/16
# Kalshi Event: KXNFLAFCNORTH-25
# Polymarket Event ID: 23659
# Similarity: 0.9229649901390076
# Found 3 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23659
#   Checking 3 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLAFCNORTH-25-PIT, Polymarket ID=540270
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.6200 (fee: $0.00)
#         Kalshi NO price: $0.4200 (fee: $0.0200)
#         Total cost: $1.0600, Profit: $-0.0600 (-6.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.4100 (fee: $0.00)
#         Kalshi YES price: $0.5900 (fee: $0.0200)
#         Total cost: $1.0200, Profit: $-0.0200 (-2.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLAFCNORTH-25-CIN, Polymarket ID=540271
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0480 (fee: $0.00)
#         Kalshi NO price: $0.9500 (fee: $0.0100)
#         Total cost: $1.0080, Profit: $-0.0080 (-0.80%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9760 (fee: $0.00)
#         Kalshi YES price: $0.0600 (fee: $0.0100)
#         Total cost: $1.0460, Profit: $-0.0460 (-4.60%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXNFLAFCNORTH-25-BAL, Polymarket ID=540272
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.3900 (fee: $0.00)
#         Kalshi NO price: $0.6200 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.6500 (fee: $0.00)
#         Kalshi YES price: $0.3900 (fee: $0.0200)
#         Total cost: $1.0600, Profit: $-0.0600 (-6.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 3 matched pair(s)
#
# ================================================================================
# Processing pair 40/16
# Kalshi Event: KXLCPIMAXYOY-25
# Polymarket Event ID: 17880
# Similarity: 0.9225614070892334
# Found 3 matched market pair(s) in JSON
# fetching polymarket event using event_id:  17880
#   Checking 3 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXLCPIMAXYOY-25-P3.99, Polymarket ID=522146
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0140 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0140, Profit: $-0.0140 (-1.40%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9880 (fee: $0.00)
#         Kalshi YES price: $0.0100 (fee: $0.0100)
#         Total cost: $1.0080, Profit: $-0.0080 (-0.80%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXLCPIMAXYOY-25-P4.99, Polymarket ID=522147
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0190 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0190, Profit: $-0.0190 (-1.90%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9930 (fee: $0.00)
#         Kalshi YES price: $0.0100 (fee: $0.0100)
#         Total cost: $1.0130, Profit: $-0.0130 (-1.30%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXLCPIMAXYOY-25-P7.99, Polymarket ID=522149
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0060 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0060, Profit: $-0.0060 (-0.60%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9960 (fee: $0.00)
#         Kalshi YES price: $0.0100 (fee: $0.0100)
#         Total cost: $1.0160, Profit: $-0.0160 (-1.60%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 3 matched pair(s)
#
# ================================================================================
# Processing pair 41/16
# Kalshi Event: KXNFLNFCCHAMP-25
# Polymarket Event ID: 23657
# Similarity: 0.9222679734230042
# Found 11 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23657
#   Checking 11 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLNFCCHAMP-25-CAR, Polymarket ID=540240
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0280 (fee: $0.00)
#         Kalshi NO price: $0.9900 (fee: $0.0100)
#         Total cost: $1.0280, Profit: $-0.0280 (-2.80%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9880 (fee: $0.00)
#         Kalshi YES price: $0.0200 (fee: $0.0100)
#         Total cost: $1.0180, Profit: $-0.0180 (-1.80%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLNFCCHAMP-25-CHI, Polymarket ID=540241
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0550 (fee: $0.00)
#         Kalshi NO price: $0.9600 (fee: $0.0100)
#         Total cost: $1.0250, Profit: $-0.0250 (-2.50%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9480 (fee: $0.00)
#         Kalshi YES price: $0.0500 (fee: $0.0100)
#         Total cost: $1.0080, Profit: $-0.0080 (-0.80%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXNFLNFCCHAMP-25-DAL, Polymarket ID=540242
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0180 (fee: $0.00)
#         Kalshi NO price: $0.9900 (fee: $0.0100)
#         Total cost: $1.0180, Profit: $-0.0180 (-1.80%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9910 (fee: $0.00)
#         Kalshi YES price: $0.0200 (fee: $0.0100)
#         Total cost: $1.0210, Profit: $-0.0210 (-2.10%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #4: Kalshi ticker=KXNFLNFCCHAMP-25-DET, Polymarket ID=540243
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0870 (fee: $0.00)
#         Kalshi NO price: $0.9400 (fee: $0.0100)
#         Total cost: $1.0370, Profit: $-0.0370 (-3.70%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9380 (fee: $0.00)
#         Kalshi YES price: $0.0700 (fee: $0.0100)
#         Total cost: $1.0180, Profit: $-0.0180 (-1.80%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #5: Kalshi ticker=KXNFLNFCCHAMP-25-GB, Polymarket ID=540244
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.1800 (fee: $0.00)
#         Kalshi NO price: $0.8400 (fee: $0.0100)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.8500 (fee: $0.00)
#         Kalshi YES price: $0.1700 (fee: $0.0100)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #6: Kalshi ticker=KXNFLNFCCHAMP-25-LA, Polymarket ID=540245
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.3100 (fee: $0.00)
#         Kalshi NO price: $0.7000 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.7100 (fee: $0.00)
#         Kalshi YES price: $0.3100 (fee: $0.0200)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #7: Kalshi ticker=KXNFLNFCCHAMP-25-MIN, Polymarket ID=540246
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0020 (fee: $0.00)
#         Kalshi NO price: $1.0000 (fee: $0.0000)
#         Total cost: $1.0020, Profit: $-0.0020 (-0.20%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9990 (fee: $0.00)
#         Kalshi YES price: $0.0100 (fee: $0.0100)
#         Total cost: $1.0190, Profit: $-0.0190 (-1.90%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #8: Kalshi ticker=KXNFLNFCCHAMP-25-PHI, Polymarket ID=540249
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.1300 (fee: $0.00)
#         Kalshi NO price: $0.8800 (fee: $0.0100)
#         Total cost: $1.0200, Profit: $-0.0200 (-2.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.8900 (fee: $0.00)
#         Kalshi YES price: $0.1300 (fee: $0.0100)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #9: Kalshi ticker=KXNFLNFCCHAMP-25-SF, Polymarket ID=540250
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0620 (fee: $0.00)
#         Kalshi NO price: $0.9300 (fee: $0.0100)
#         Total cost: $1.0020, Profit: $-0.0020 (-0.20%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9400 (fee: $0.00)
#         Kalshi YES price: $0.0800 (fee: $0.0100)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #10: Kalshi ticker=KXNFLNFCCHAMP-25-SEA, Polymarket ID=540251
#     ✅ Found arbitrage opportunity: Strategy 1 (Buy YES Poly + Buy NO Kalshi), Profit: 0.50%
#   Matched pair #11: Kalshi ticker=KXNFLNFCCHAMP-25-TB, Polymarket ID=540252
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0490 (fee: $0.00)
#         Kalshi NO price: $0.9700 (fee: $0.0100)
#         Total cost: $1.0290, Profit: $-0.0290 (-2.90%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9890 (fee: $0.00)
#         Kalshi YES price: $0.0400 (fee: $0.0100)
#         Total cost: $1.0390, Profit: $-0.0390 (-3.90%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ✅ Found 1 arbitrage opportunity(ies) across 11 matched pair(s)!
#
# ================================================================================
# Processing pair 45/16
# Kalshi Event: KXNFLNFCWEST-25
# Polymarket Event ID: 23665
# Similarity: 0.9213566184043884
# Found 3 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23665
#   Checking 3 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLNFCWEST-25-SF, Polymarket ID=540290
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.1300 (fee: $0.00)
#         Kalshi NO price: $0.8800 (fee: $0.0100)
#         Total cost: $1.0200, Profit: $-0.0200 (-2.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9000 (fee: $0.00)
#         Kalshi YES price: $0.1300 (fee: $0.0100)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLNFCWEST-25-LA, Polymarket ID=540291
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.5500 (fee: $0.00)
#         Kalshi NO price: $0.4500 (fee: $0.0200)
#         Total cost: $1.0200, Profit: $-0.0200 (-2.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.4900 (fee: $0.00)
#         Kalshi YES price: $0.5600 (fee: $0.0200)
#         Total cost: $1.0700, Profit: $-0.0700 (-7.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXNFLNFCWEST-25-SEA, Polymarket ID=540292
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.3400 (fee: $0.00)
#         Kalshi NO price: $0.6800 (fee: $0.0200)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.6900 (fee: $0.00)
#         Kalshi YES price: $0.3300 (fee: $0.0200)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 3 matched pair(s)
#
# ================================================================================
# Processing pair 48/16
# Kalshi Event: KXNFLAFCSOUTH-25
# Polymarket Event ID: 23660
# Similarity: 0.9209510684013368
# Found 3 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23660
#   Checking 3 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLAFCSOUTH-25-HOU, Polymarket ID=540274
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.3780 (fee: $0.00)
#         Kalshi NO price: $0.6500 (fee: $0.0200)
#         Total cost: $1.0480, Profit: $-0.0480 (-4.80%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.6420 (fee: $0.00)
#         Kalshi YES price: $0.3700 (fee: $0.0200)
#         Total cost: $1.0320, Profit: $-0.0320 (-3.20%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLAFCSOUTH-25-IND, Polymarket ID=540275
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.0390 (fee: $0.00)
#         Kalshi NO price: $0.9700 (fee: $0.0100)
#         Total cost: $1.0190, Profit: $-0.0190 (-1.90%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.9650 (fee: $0.00)
#         Kalshi YES price: $0.0400 (fee: $0.0100)
#         Total cost: $1.0150, Profit: $-0.0150 (-1.50%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #3: Kalshi ticker=KXNFLAFCSOUTH-25-JAC, Polymarket ID=540276
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.6100 (fee: $0.00)
#         Kalshi NO price: $0.4100 (fee: $0.0200)
#         Total cost: $1.0400, Profit: $-0.0400 (-4.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.4200 (fee: $0.00)
#         Kalshi YES price: $0.6200 (fee: $0.0200)
#         Total cost: $1.0600, Profit: $-0.0600 (-6.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 3 matched pair(s)
#
# ================================================================================
# Processing pair 49/16
# Kalshi Event: KXPRESPARTY-2028
# Polymarket Event ID: 33228
# Similarity: 0.920861840248108
# Found 2 matched market pair(s) in JSON
# fetching polymarket event using event_id:  33228
#   Checking 2 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXPRESPARTY-2028-R, Polymarket ID=565064
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.4600 (fee: $0.00)
#         Kalshi NO price: $0.5500 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.5500 (fee: $0.00)
#         Kalshi YES price: $0.4600 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXPRESPARTY-2028-D, Polymarket ID=565065
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.5500 (fee: $0.00)
#         Kalshi NO price: $0.4600 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.4600 (fee: $0.00)
#         Kalshi YES price: $0.5500 (fee: $0.0200)
#         Total cost: $1.0300, Profit: $-0.0300 (-3.00%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 2 matched pair(s)
#
# ================================================================================
# Processing pair 50/16
# Kalshi Event: KXNFLAFCEAST-25
# Polymarket Event ID: 23663
# Similarity: 0.9206597805023192
# Found 2 matched market pair(s) in JSON
# fetching polymarket event using event_id:  23663
#   Checking 2 matched market pair(s) for arbitrage...
#   Matched pair #1: Kalshi ticker=KXNFLAFCEAST-25-BUF, Polymarket ID=540282
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.1930 (fee: $0.00)
#         Kalshi NO price: $0.8300 (fee: $0.0100)
#         Total cost: $1.0330, Profit: $-0.0330 (-3.30%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.8570 (fee: $0.00)
#         Kalshi YES price: $0.1900 (fee: $0.0200)
#         Total cost: $1.0670, Profit: $-0.0670 (-6.70%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
#   Matched pair #2: Kalshi ticker=KXNFLAFCEAST-25-NE, Polymarket ID=540285
#     ❌ No arbitrage opportunity for this matched pair
#       Strategy 1 (Buy YES Poly + Buy NO Kalshi):
#         Poly YES price: $0.8400 (fee: $0.00)
#         Kalshi NO price: $0.2000 (fee: $0.0200)
#         Total cost: $1.0600, Profit: $-0.0600 (-6.00%)
#       Strategy 2 (Buy NO Poly + Buy YES Kalshi):
#         Poly NO price: $0.1910 (fee: $0.00)
#         Kalshi YES price: $0.8100 (fee: $0.0200)
#         Total cost: $1.0210, Profit: $-0.0210 (-2.10%)
#       Reason: Both strategies have total cost >= $1.00 (including fees), so no arbitrage exists
# ❌ No arbitrage opportunities found for 2 matched pair(s)

# %%
# Display all arbitrage opportunities found
if all_opportunities:
    print(f"\n{'='*80}")
    print(f"SUMMARY: Found {len(all_opportunities)} total arbitrage opportunities from matched market pairs")
    print(f"{'='*80}\n")
    
    opportunities_df = pd.DataFrame(all_opportunities)
    
    # Sort by profit percentage (highest first)
    opportunities_df = opportunities_df.sort_values('profit_pct', ascending=False)

    # Display all opportunities
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    pd.set_option('display.max_colwidth', 50)
    
    print(opportunities_df.to_string())
    
    # Save to CSV
    output_file = "../data/arbitrage_opportunities.csv"
    opportunities_df.to_csv(output_file, index=False)
    print(f"\n✅ Saved {len(all_opportunities)} opportunities to {output_file}")
else:
    print("\n❌ No arbitrage opportunities found in any of the matched market pairs")
# Out:
# ================================================================================
# SUMMARY: Found 4 total arbitrage opportunities from matched market pairs
# ================================================================================
#
#                                   strategy poly_market_id                                                             poly_market_title         kalshi_market_ticker                                                                               kalshi_market_title  poly_yes_price  poly_yes_fee  kalshi_no_price  kalshi_no_fee  total_cost  total_fees  profit  profit_pct       kalshi_event_ticker  polymarket_event_id  poly_no_price  poly_no_fee  kalshi_yes_price  kalshi_yes_fee
# 1  Buy NO on Polymarket, Buy YES on Kalshi         573656                                  Will Bitcoin hit $150k by December 31, 2026?  KXBTC2026250-27JAN01-250000                                       Will Bitcoin be above $250000 by Jan 1, 2027 at 12:00AM ET?             NaN           NaN              NaN            NaN       0.780        0.01   0.220        22.0      KXBTC2026250-27JAN01                36173           0.67          0.0              0.10            0.01
# 2  Buy NO on Polymarket, Buy YES on Kalshi         578157  Will any 2026 FIFA World Cup game scheduled in the U.S. be relocated abroad?     KXFIFAUSPULLGAME-26JUN11  Will any 2026 FIFA World Cup game scheduled in the U.S. be relocated abroad before Jun 11, 2026?             NaN           NaN              NaN            NaN       0.970        0.01   0.030         3.0  KXFIFAUSPULLGAME-26JUN11                38368           0.89          0.0              0.07            0.01
# 3  Buy YES on Polymarket, Buy NO on Kalshi         540251                              Will the Seahawks win the 2026 NFC Championship?         KXNFLNFCCHAMP-25-SEA                                                             Pro Football NFC Championship Winner?           0.165           0.0             0.81           0.02       0.995        0.02   0.005         0.5          KXNFLNFCCHAMP-25                23657            NaN          NaN               NaN             NaN
# 0  Buy YES on Polymarket, Buy NO on Kalshi         591900                                Will Greta Thunberg enter Gaza by December 31?          KXGRETAGAZA-26JAN01                                                Will Greta Thunberg visit Gaza before Jan 1, 2026?           0.006           0.0             0.98           0.01       0.996        0.01   0.004         0.4       KXGRETAGAZA-26JAN01                40869            NaN          NaN               NaN             NaN
#
# ✅ Saved 4 opportunities to ../data/arbitrage_opportunities.csv

# %%
# Detailed view of top opportunities
if all_opportunities:
    opportunities_df = pd.DataFrame(all_opportunities)
    opportunities_df = opportunities_df.sort_values('profit_pct', ascending=False)
    
    print("\n" + "="*80)
    print("TOP ARBITRAGE OPPORTUNITIES (by profit %)")
    print("="*80 + "\n")
    
    for idx, row in opportunities_df.head(10).iterrows():
        print(f"\nOpportunity #{idx + 1}")
        print(f"  Strategy: {row['strategy']}")
        print(f"  Profit: {row['profit_pct']:.2f}% (${row['profit']:.4f} per $1)")
        print(f"  Total Cost: ${row['total_cost']:.4f} (including fees)")
        print(f"  Total Fees: ${row['total_fees']:.4f}")
        print(f"  Kalshi Event: {row['kalshi_event_ticker']}")
        print(f"  Kalshi Market: {row['kalshi_market_ticker']}")
        print(f"  Kalshi Market Title: {row['kalshi_market_title']}")
        print(f"  Polymarket Event ID: {row['polymarket_event_id']}")
        print(f"  Polymarket Market ID: {row['poly_market_id']}")
        print(f"  Polymarket Market Title: {row['poly_market_title']}")
        
        # Show prices and fees based on strategy
        if 'poly_yes_price' in row and pd.notna(row['poly_yes_price']):
            print(f"  Polymarket YES Price: ${row['poly_yes_price']:.4f} (Fee: $0.00 - no fees on Polymarket)")
            print(f"  Kalshi NO Price: ${row['kalshi_no_price']:.4f} (Fee: ${row['kalshi_no_fee']:.4f})")
        else:
            print(f"  Polymarket NO Price: ${row['poly_no_price']:.4f} (Fee: $0.00 - no fees on Polymarket)")
            print(f"  Kalshi YES Price: ${row['kalshi_yes_price']:.4f} (Fee: ${row['kalshi_yes_fee']:.4f})")
        print("-" * 80)
# Out:
# ================================================================================
# TOP ARBITRAGE OPPORTUNITIES (by profit %)
# ================================================================================
#
#
# Opportunity #2
#   Strategy: Buy NO on Polymarket, Buy YES on Kalshi
#   Profit: 22.00% ($0.2200 per $1)
#   Total Cost: $0.7800 (including fees)
#   Total Fees: $0.0100
#   Kalshi Event: KXBTC2026250-27JAN01
#   Kalshi Market: KXBTC2026250-27JAN01-250000
#   Kalshi Market Title: Will Bitcoin be above $250000 by Jan 1, 2027 at 12:00AM ET?
#   Polymarket Event ID: 36173
#   Polymarket Market ID: 573656
#   Polymarket Market Title: Will Bitcoin hit $150k by December 31, 2026?
#   Polymarket NO Price: $0.6700 (Fee: $0.00 - no fees on Polymarket)
#   Kalshi YES Price: $0.1000 (Fee: $0.0100)
# --------------------------------------------------------------------------------
#
# Opportunity #3
#   Strategy: Buy NO on Polymarket, Buy YES on Kalshi
#   Profit: 3.00% ($0.0300 per $1)
#   Total Cost: $0.9700 (including fees)
#   Total Fees: $0.0100
#   Kalshi Event: KXFIFAUSPULLGAME-26JUN11
#   Kalshi Market: KXFIFAUSPULLGAME-26JUN11
#   Kalshi Market Title: Will any 2026 FIFA World Cup game scheduled in the U.S. be relocated abroad before Jun 11, 2026?
#   Polymarket Event ID: 38368
#   Polymarket Market ID: 578157
#   Polymarket Market Title: Will any 2026 FIFA World Cup game scheduled in the U.S. be relocated abroad?
#   Polymarket NO Price: $0.8900 (Fee: $0.00 - no fees on Polymarket)
#   Kalshi YES Price: $0.0700 (Fee: $0.0100)
# --------------------------------------------------------------------------------
#
# Opportunity #4
#   Strategy: Buy YES on Polymarket, Buy NO on Kalshi
#   Profit: 0.50% ($0.0050 per $1)
#   Total Cost: $0.9950 (including fees)
#   Total Fees: $0.0200
#   Kalshi Event: KXNFLNFCCHAMP-25
#   Kalshi Market: KXNFLNFCCHAMP-25-SEA
#   Kalshi Market Title: Pro Football NFC Championship Winner?
#   Polymarket Event ID: 23657
#   Polymarket Market ID: 540251
#   Polymarket Market Title: Will the Seahawks win the 2026 NFC Championship?
#   Polymarket YES Price: $0.1650 (Fee: $0.00 - no fees on Polymarket)
#   Kalshi NO Price: $0.8100 (Fee: $0.0200)
# --------------------------------------------------------------------------------
#
# Opportunity #1
#   Strategy: Buy YES on Polymarket, Buy NO on Kalshi
#   Profit: 0.40% ($0.0040 per $1)
#   Total Cost: $0.9960 (including fees)
#   Total Fees: $0.0100
#   Kalshi Event: KXGRETAGAZA-26JAN01
#   Kalshi Market: KXGRETAGAZA-26JAN01
#   Kalshi Market Title: Will Greta Thunberg visit Gaza before Jan 1, 2026?
#   Polymarket Event ID: 40869
#   Polymarket Market ID: 591900
#   Polymarket Market Title: Will Greta Thunberg enter Gaza by December 31?
#   Polymarket YES Price: $0.0060 (Fee: $0.00 - no fees on Polymarket)
#   Kalshi NO Price: $0.9800 (Fee: $0.0100)
# --------------------------------------------------------------------------------

# %%
# Summary statistics
if all_opportunities:
    opportunities_df = pd.DataFrame(all_opportunities)
    
    print("\n" + "="*80)
    print("ARBITRAGE OPPORTUNITIES SUMMARY STATISTICS")
    print("="*80 + "\n")
    
    print(f"Total Opportunities Found: {len(opportunities_df)}")
    print(f"Average Profit: {opportunities_df['profit_pct'].mean():.2f}%")
    print(f"Median Profit: {opportunities_df['profit_pct'].median():.2f}%")
    print(f"Max Profit: {opportunities_df['profit_pct'].max():.2f}%")
    print(f"Min Profit: {opportunities_df['profit_pct'].min():.2f}%")
    
    print(f"\nStrategies:")
    print(opportunities_df['strategy'].value_counts())
    
    print(f"\nUnique Event Pairs with Opportunities: {opportunities_df[['kalshi_event_ticker', 'polymarket_event_id']].drop_duplicates().shape[0]}")
    print(f"Total Matched Pairs Checked: {len(arbitrage_possible)} event pairs with matched markets")
    
    # Show distribution of profits
    print(f"\nProfit Distribution:")
    print(opportunities_df['profit_pct'].describe())
# Out:
# ================================================================================
# ARBITRAGE OPPORTUNITIES SUMMARY STATISTICS
# ================================================================================
#
# Total Opportunities Found: 4
# Average Profit: 6.47%
# Median Profit: 1.75%
# Max Profit: 22.00%
# Min Profit: 0.40%
#
# Strategies:
# strategy
# Buy YES on Polymarket, Buy NO on Kalshi    2
# Buy NO on Polymarket, Buy YES on Kalshi    2
# Name: count, dtype: int64
#
# Unique Event Pairs with Opportunities: 4
# Total Matched Pairs Checked: 16 event pairs with matched markets
#
# Profit Distribution:
# count     4.000000
# mean      6.475000
# std      10.419653
# min       0.400000
# 25%       0.475000
# 50%       1.750000
# 75%       7.750000
# max      22.000000
# Name: profit_pct, dtype: float64
